# %%
#Import 
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#Hyperparameters
f = [16, 32, 64, 128, 256] #number of filters for each layer
    #The number of filters is the number of neurons, since each neuron performs a different convolution on the input 
    #to the layer (more precisely, the neurons' input weights form convolution kernels).
    
    #A feature map is the result of applying a filter (thus, you have as many feature maps as filters), 
    #and its size is a result of window/kernel size of your filter and stride.
img_size = 128
batch_size = 8
    #The batch size defines the number of samples that will be propagated through the network.
    #For instance, let's say you have 1050 training samples and you want to set up a batch_size equal to 100. The algorithm takes the first 100 samples (from 1st to 100th) from the training dataset and trains the network. Next, it takes the second 100 samples (from 101st to 200th) and trains the network again. We can keep doing this procedure until we have propagated all samples through of the network. Problem might happen with the last set of samples. In our example, we've used 1050 which is not divisible by 100 without remainder. The simplest solution is just to get the final 50 samples and train the network.
    #Advantages of using a batch size < number of all samples: 
    #It requires less memory. Since you train the network using fewer samples, the overall training procedure requires less memory. That's especially important if you are not able to fit the whole dataset in your machine's memory.
    #Typically networks train faster with mini-batches. That's because we update the weights after each propagation. In our example we've propagated 11 batches (10 of them had 100 samples and 1 had 50 samples) and after each of them we've updated our network's parameters. If we used all samples during propagation we would make only 1 update for the network's parameter.
    #Disadvantages of using a batch size < number of all samples:
    #The smaller the batch the less accurate the estimate of the gradient will be. In the figure below, you can see that the direction of the mini-batch gradient (green color) fluctuates much more in comparison to the direction of the full batch gradient (blue color).
epochs = 15
    #In terms of artificial neural networks, an epoch refers to one cycle through the full training dataset. Usually, training a neural network takes more than a few epochs. In other words, if we feed a neural network the training data for more than one epoch in different patterns, we hope for a better generalization when given a new "unseen" input (test data). An epoch is often mixed up with an iteration. Iterations is the number of batches or steps through partitioned packets of the training data, needed to complete one epoch.  Heuristically, one motivation is that (especially for large but finite training sets) it gives the network a chance to see the previous data to readjust the model parameters so that the model is not biased towards the last few data points during training.  
training_path = "dataset/stage1_train/"
test_path = "dataset/stage1_test/"
training_img_ids = next(os.walk(training_path))[1]
test_img_ids = next(os.walk(test_path))[1]

# %%
# Data Loader
class DataLoader(keras.utils.Sequence):
    #batch size because loading all images by once will be to heavy; image size 128 because all images have different sizes and have to be resized.
    def __init__(self, img_ids, path, batch_size = 4, img_size = 128):
        self.img_ids = img_ids
        self.path = path
        self.batch_size = batch_size
        self.img_size=img_size
        self.on_epoch_end()
    
    #function to load the single image and the single mask + all masks for a single image using the ids
    def __load__(self, img_id_name):
        #set paths
        img_path = os.path.join(self.path, img_id_name, "images", img_id_name) + ".png"
        mask_path = os.path.join(self.path, img_id_name, "masks/")
        all_masks = os.listdir(mask_path)
        
        #read the images
        img = cv2.imread(img_path, 1) # 1 = read in in color form; 0 would be grey scale
        img = cv2.resize(img, (self.img_size, self.img_size))
        mask = np.zeros((self.img_size, self. img_size, 1))
        
        #read the masks
        for i in all_masks:
            _mask_path = mask_path + i
            _mask_img = cv2.imread(_mask_path, -1)
            _mask_img = cv2. resize(_mask_img, (self.img_size, self.img_size))
            _mask_img = np.expand_dims(_mask_img, axis = -1)
            mask = np.maximum(mask, _mask_img) #maximum value here will be 255 -> so this has to be normalized
        
        #normalization of img and mask
        img=img/255.0
        mask=mask/255.0
        
        return img, mask
    
     #Gets batch at position index. Should return a complete batch Mandatory function for a Sequence
    def __getitem__(self, index):
        if(index+1)*self.batch_size > len(self.img_ids):
            self.batch_size = len(self.img_ids) - index*self.batch_size
        
        files_batch = self.img_ids[index*self.batch_size : (index+1)*self.batch_size]
        
        img = []
        mask  = []
        
        for id_name in files_batch:
            _image, _mask = self.__load__(id_name)
            img.append(_image)
            mask.append(_mask)
            
        img = np.array(img)
        mask  = np.array(mask)
        
        return img, mask
    #returns complete batch as image and mask are arrays containing the images and masks of the actual batch
    
    
    
    #Number of batch in the Sequence. Mandatory function for a Sequence
    def __len__(self):
        return int(np.ceil(len(self.img_ids)/float(self.batch_size)))
    
    
    
     #Method called at the end of every epoch.
    def on_epoch_end(self):
        pass

# %%
def conv_layer(x,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    conv1 = layers.Conv2D(filters=filters,kernel_size=kernel_size,padding=padding,activation="relu")
    norm1 = layers.BatchNormalization()
    x = conv1(x)
    x = norm1(x)
    return x

def down_block(x,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    pool = layers.MaxPool2D((2,2),(2,2))
    x = conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    x = conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    p = pool(x)
    return x,p

def plateau_block(x,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    conv_transpose = layers.Conv2DTranspose(filters//2,kernel_size=(2,2),strides=(2,2))
    x = conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    x = conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    up = conv_transpose(x)
    return up

def up_block(x,p,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    concat = layers.Concatenate()([x,p])
    conv_transpose = layers.Conv2DTranspose(filters,kernel_size=(2,2),strides=(2,2))
    x = conv_layer(concat,filters,kernel_size,padding,strides,time_steps)
    x = conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    up = conv_transpose(x)
    return up

def output_layer(x,p,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    concat = layers.Concatenate()([x,p])
    out_conv = keras.layers.Conv2D(1, (1, 1), padding="same", activation="relu")
    x = conv_layer(concat,filters,kernel_size,padding,strides,time_steps)
    x = conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    outs = out_conv(x)
    return outs

# %%
#f = [16, 32, 64, 128, 256] #number of filters for each layer

#RUNet Model as described in Fig. 3 https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
def UNet():
    inputs = keras.layers.Input((img_size, img_size, 3)) #3 because of rgb
    #inputs = tf.random.normal((1,224,224,3))
    #downsampling
    p0 = inputs
    print(p0.shape)
    c1, p1 = down_block(p0, f[0],time_steps=0) #16
    print(c1.shape,p1.shape)
    c2, p2 = down_block(p1, f[1],time_steps=0) #32
    print(c2.shape,p2.shape)
    c3, p3 = down_block(p2, f[2],time_steps=0) #64
    print(c3.shape,p3.shape)
    c4, p4 = down_block(p3, f[3],time_steps=0) #128
    print(c4.shape,p4.shape)
    #convolution_block before upsampling
    cn = plateau_block(p4, f[4],time_steps=0) #128
    print(cn.shape)
    
    #upsampling
    u1 = up_block(cn, c4, f[3],time_steps=0) #128
    print(cn.shape,c4.shape)
    u2 = up_block(u1, c3, f[2],time_steps=0) #64
    print(u1.shape,c3.shape)
    u3 = up_block(u2, c2, f[1],time_steps=0) #32
    print(u2.shape,c2.shape)
    outputs = output_layer(u3, c1, f[0],time_steps=0) #16
    print(u3.shape,c1.shape)
    
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model = UNet()
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"]) #Configures the model for training.
model.summary()
# Out:
# (None, 128, 128, 3)
# (None, 128, 128, 16) (None, 64, 64, 16)
# (None, 64, 64, 32) (None, 32, 32, 32)
# (None, 32, 32, 64) (None, 16, 16, 64)
# (None, 16, 16, 128) (None, 8, 8, 128)
# (None, 16, 16, 128)
# (None, 16, 16, 128) (None, 16, 16, 128)
# (None, 32, 32, 128) (None, 32, 32, 64)
# (None, 64, 64, 64) (None, 64, 64, 32)
# (None, 128, 128, 32) (None, 128, 128, 16)
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 128, 128, 16) 448         input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 128, 128, 16) 64          conv2d_238[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 128, 128, 16) 2320        batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 128, 128, 16) 64          conv2d_239[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 64, 64, 16)   0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 64, 64, 32)   128         conv2d_240[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 64, 64, 32)   9248        batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 64, 64, 32)   128         conv2d_241[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 32, 32, 32)   0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 32, 32, 64)   256         conv2d_242[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 32, 32, 64)   36928       batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 32, 32, 64)   256         conv2d_243[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 16, 16, 64)   0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 16, 16, 128)  73856       max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 16, 16, 128)  512         conv2d_244[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 16, 16, 128)  147584      batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 16, 16, 128)  512         conv2d_245[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 8, 8, 128)    0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 8, 8, 256)    295168      max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 8, 8, 256)    1024        conv2d_246[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 8, 8, 256)    590080      batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 8, 8, 256)    1024        conv2d_247[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 16, 16, 128)  131200      batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 16, 16, 256)  0           conv2d_transpose_24[0][0]
#                                                                  batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 16, 16, 128)  295040      concatenate_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 16, 16, 128)  512         conv2d_248[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 16, 16, 128)  147584      batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 16, 16, 128)  512         conv2d_249[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 32, 32, 128)  65664       batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 32, 32, 192)  0           conv2d_transpose_25[0][0]
#                                                                  batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 32, 32, 64)   110656      concatenate_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 32, 32, 64)   256         conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 32, 32, 64)   36928       batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 32, 32, 64)   256         conv2d_251[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_26 (Conv2DTran (None, 64, 64, 64)   16448       batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 64, 64, 96)   0           conv2d_transpose_26[0][0]
#                                                                  batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 64, 64, 32)   27680       concatenate_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 64, 64, 32)   128         conv2d_252[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 64, 64, 32)   9248        batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 64, 64, 32)   128         conv2d_253[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_27 (Conv2DTran (None, 128, 128, 32) 4128        batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 128, 128, 48) 0           conv2d_transpose_27[0][0]
#                                                                  batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 128, 128, 16) 6928        concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 128, 128, 16) 64          conv2d_255[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 128, 128, 16) 2320        batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 128, 128, 16) 64          conv2d_256[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 128, 128, 1)  17          batch_normalization_143[0][0]
# ==================================================================================================
# Total params: 2,038,497
# Trainable params: 2,035,553
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
#Training: Unet
training_loader = DataLoader(training_img_ids, training_path, img_size=img_size, batch_size=batch_size)
test_loader = DataLoader(test_img_ids, test_path, img_size=img_size, batch_size=batch_size)

train_steps = len(training_img_ids)//batch_size
test_steps = len(test_img_ids)//batch_size

model.fit_generator(training_loader, validation_data=test_loader, steps_per_epoch=train_steps, validation_steps=test_steps, 
                    epochs=epochs)
# Out:
# Epoch 1/15
# 81/81 [==============================] - 86s 1s/step - loss: 1.1573 - acc: 0.8661 - val_loss: 1.7077 - val_acc: 0.8649
# Epoch 2/15
# 81/81 [==============================] - 76s 938ms/step - loss: 0.6061 - acc: 0.9071 - val_loss: 0.8233 - val_acc: 0.8660
# Epoch 3/15
# 81/81 [==============================] - 76s 934ms/step - loss: 0.3858 - acc: 0.9248 - val_loss: 0.1140 - val_acc: 0.9906
# Epoch 4/15
# 81/81 [==============================] - 77s 946ms/step - loss: 0.3452 - acc: 0.9210 - val_loss: 0.1218 - val_acc: 0.9906
# Epoch 5/15
# 81/81 [==============================] - 75s 930ms/step - loss: 0.2451 - acc: 0.9299 - val_loss: 0.0981 - val_acc: 0.9906
# Epoch 6/15
# 81/81 [==============================] - 74s 911ms/step - loss: 0.3209 - acc: 0.9167 - val_loss: 0.0266 - val_acc: 0.9935
# Epoch 7/15
# 81/81 [==============================] - 77s 947ms/step - loss: 0.2254 - acc: 0.9256 - val_loss: 0.0183 - val_acc: 0.9924
# Epoch 8/15
# 81/81 [==============================] - 76s 940ms/step - loss: 0.2005 - acc: 0.9283 - val_loss: 0.0121 - val_acc: 0.9940
# Epoch 9/15
# 81/81 [==============================] - 76s 937ms/step - loss: 0.1746 - acc: 0.9328 - val_loss: 0.0098 - val_acc: 0.9948
# Epoch 10/15
# 81/81 [==============================] - 75s 932ms/step - loss: 0.1828 - acc: 0.9320 - val_loss: 0.0088 - val_acc: 0.9951
# Epoch 11/15
# 81/81 [==============================] - 77s 952ms/step - loss: 0.1549 - acc: 0.9378 - val_loss: 0.0087 - val_acc: 0.9958
# Epoch 12/15
# 81/81 [==============================] - 76s 933ms/step - loss: 0.1508 - acc: 0.9378 - val_loss: 0.0094 - val_acc: 0.9954
# Epoch 13/15
# 81/81 [==============================] - 76s 944ms/step - loss: 0.1311 - acc: 0.9441 - val_loss: 0.0114 - val_acc: 0.9949
# Epoch 14/15
# 81/81 [==============================] - 76s 935ms/step - loss: 0.1406 - acc: 0.9382 - val_loss: 0.0077 - val_acc: 0.9958
# Epoch 15/15
# 81/81 [==============================] - 74s 915ms/step - loss: 0.1343 - acc: 0.9423 - val_loss: 0.0078 - val_acc: 0.9957

# %%
def _recurrent_conv_layer(x,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    conv_base = layers.Conv2D(filters=filters,kernel_size=kernel_size,padding=padding)
    x = conv_base(x)
    norm = layers.BatchNormalization()
    #x = norm(x)
    conv_t = layers.Conv2D(filters=filters,kernel_size=kernel_size,padding=padding)
    
    add = layers.Add()
    x_t = tf.nn.relu(conv_t(x))#t0
    x_t = norm(x_t)
    for step in range(time_steps):
        x_t = norm(tf.nn.relu(add([x,conv_t(x_t)])))
    
    return x_t

def recurrent_down_block(x,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    pool = layers.MaxPool2D((2,2),(2,2))
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    p = pool(x)
    return x,p

def recurrent_plateau_block(x,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    conv_transpose = layers.Conv2DTranspose(filters//2,kernel_size=(2,2),strides=(2,2))
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    up = conv_transpose(x)
    return up

def recurrent_up_block(x,p,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    concat = layers.Concatenate()([x,p])
    conv_transpose = layers.Conv2DTranspose(filters,kernel_size=(2,2),strides=(2,2))
    x = _recurrent_conv_layer(concat,filters,kernel_size,padding,strides,time_steps)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    up = conv_transpose(x)
    return up

def recurrent_output_layer(x,p,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    concat = layers.Concatenate()([x,p])
    out_conv = keras.layers.Conv2D(1, (1, 1), padding="same", activation="relu")
    x = _recurrent_conv_layer(concat,filters,kernel_size,padding,strides,time_steps)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    outs = out_conv(x)
    return outs

# %%
#f = [16, 32, 64, 128, 256] #number of filters for each layer

#RUNet Model as described in Fig. 3 https://arxiv.org/ftp/arxiv/papers/1802/1802.06955.pdf
def RUNet():
    inputs = keras.layers.Input((img_size, img_size, 3)) #3 because of rgb
    #inputs = tf.random.normal((1,224,224,3))
    #downsampling
    p0 = inputs
    print(p0.shape)
    c1, p1 = recurrent_down_block(p0, f[0]) #16
    print(c1.shape,p1.shape)
    c2, p2 = recurrent_down_block(p1, f[1]) #32
    print(c2.shape,p2.shape)
    c3, p3 = recurrent_down_block(p2, f[2]) #64
    print(c3.shape,p3.shape)
    c4, p4 = recurrent_down_block(p3, f[3]) #128
    print(c4.shape,p4.shape)
    #convolution_block before upsampling
    cn = recurrent_plateau_block(p4, f[4]) #128
    print(cn.shape)
    
    #upsampling
    u1 = recurrent_up_block(cn, c4, f[3]) #128
    print(cn.shape,c4.shape)
    u2 = recurrent_up_block(u1, c3, f[2]) #64
    print(u1.shape,c3.shape)
    u3 = recurrent_up_block(u2, c2, f[1]) #32
    print(u2.shape,c2.shape)
    outputs = recurrent_output_layer(u3, c1, f[0]) #16
    print(u3.shape,c1.shape)
    
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model = RUNet()
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"]) #Configures the model for training.
model.summary()
# Out:
# (None, 128, 128, 3)
# (None, 128, 128, 16) (None, 64, 64, 16)
# (None, 64, 64, 32) (None, 32, 32, 32)
# (None, 32, 32, 64) (None, 16, 16, 64)
# (None, 16, 16, 128) (None, 8, 8, 128)
# (None, 16, 16, 128)
# (None, 16, 16, 128) (None, 16, 16, 128)
# (None, 32, 32, 128) (None, 32, 32, 64)
# (None, 64, 64, 64) (None, 64, 64, 32)
# (None, 128, 128, 32) (None, 128, 128, 16)
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_331 (Conv2D)             (None, 128, 128, 16) 448         input_10[0][0]
# __________________________________________________________________________________________________
# conv2d_332 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_331[0][0]
#                                                                  batch_normalization_180[0][0]
#                                                                  batch_normalization_180[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_288 (TensorFlo [(None, 128, 128, 16 0           conv2d_332[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 128, 128, 16) 64          tf_op_layer_Relu_288[0][0]
#                                                                  tf_op_layer_Relu_289[0][0]
#                                                                  tf_op_layer_Relu_290[0][0]
# __________________________________________________________________________________________________
# add_142 (Add)                   (None, 128, 128, 16) 0           conv2d_331[0][0]
#                                                                  conv2d_332[1][0]
#                                                                  conv2d_331[0][0]
#                                                                  conv2d_332[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_289 (TensorFlo [(None, 128, 128, 16 0           add_142[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_290 (TensorFlo [(None, 128, 128, 16 0           add_142[1][0]
# __________________________________________________________________________________________________
# conv2d_333 (Conv2D)             (None, 128, 128, 16) 2320        batch_normalization_180[2][0]
# __________________________________________________________________________________________________
# conv2d_334 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_333[0][0]
#                                                                  batch_normalization_181[0][0]
#                                                                  batch_normalization_181[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_291 (TensorFlo [(None, 128, 128, 16 0           conv2d_334[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 128, 128, 16) 64          tf_op_layer_Relu_291[0][0]
#                                                                  tf_op_layer_Relu_292[0][0]
#                                                                  tf_op_layer_Relu_293[0][0]
# __________________________________________________________________________________________________
# add_143 (Add)                   (None, 128, 128, 16) 0           conv2d_333[0][0]
#                                                                  conv2d_334[1][0]
#                                                                  conv2d_333[0][0]
#                                                                  conv2d_334[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_292 (TensorFlo [(None, 128, 128, 16 0           add_143[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_293 (TensorFlo [(None, 128, 128, 16 0           add_143[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 64, 64, 16)   0           batch_normalization_181[2][0]
# __________________________________________________________________________________________________
# conv2d_335 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_336 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_335[0][0]
#                                                                  batch_normalization_182[0][0]
#                                                                  batch_normalization_182[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_294 (TensorFlo [(None, 64, 64, 32)] 0           conv2d_336[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 64, 64, 32)   128         tf_op_layer_Relu_294[0][0]
#                                                                  tf_op_layer_Relu_295[0][0]
#                                                                  tf_op_layer_Relu_296[0][0]
# __________________________________________________________________________________________________
# add_144 (Add)                   (None, 64, 64, 32)   0           conv2d_335[0][0]
#                                                                  conv2d_336[1][0]
#                                                                  conv2d_335[0][0]
#                                                                  conv2d_336[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_295 (TensorFlo [(None, 64, 64, 32)] 0           add_144[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_296 (TensorFlo [(None, 64, 64, 32)] 0           add_144[1][0]
# __________________________________________________________________________________________________
# conv2d_337 (Conv2D)             (None, 64, 64, 32)   9248        batch_normalization_182[2][0]
# __________________________________________________________________________________________________
# conv2d_338 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_337[0][0]
#                                                                  batch_normalization_183[0][0]
#                                                                  batch_normalization_183[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_297 (TensorFlo [(None, 64, 64, 32)] 0           conv2d_338[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 64, 64, 32)   128         tf_op_layer_Relu_297[0][0]
#                                                                  tf_op_layer_Relu_298[0][0]
#                                                                  tf_op_layer_Relu_299[0][0]
# __________________________________________________________________________________________________
# add_145 (Add)                   (None, 64, 64, 32)   0           conv2d_337[0][0]
#                                                                  conv2d_338[1][0]
#                                                                  conv2d_337[0][0]
#                                                                  conv2d_338[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_298 (TensorFlo [(None, 64, 64, 32)] 0           add_145[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_299 (TensorFlo [(None, 64, 64, 32)] 0           add_145[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 32, 32, 32)   0           batch_normalization_183[2][0]
# __________________________________________________________________________________________________
# conv2d_339 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_340 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_339[0][0]
#                                                                  batch_normalization_184[0][0]
#                                                                  batch_normalization_184[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_300 (TensorFlo [(None, 32, 32, 64)] 0           conv2d_340[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 32, 32, 64)   256         tf_op_layer_Relu_300[0][0]
#                                                                  tf_op_layer_Relu_301[0][0]
#                                                                  tf_op_layer_Relu_302[0][0]
# __________________________________________________________________________________________________
# add_146 (Add)                   (None, 32, 32, 64)   0           conv2d_339[0][0]
#                                                                  conv2d_340[1][0]
#                                                                  conv2d_339[0][0]
#                                                                  conv2d_340[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_301 (TensorFlo [(None, 32, 32, 64)] 0           add_146[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_302 (TensorFlo [(None, 32, 32, 64)] 0           add_146[1][0]
# __________________________________________________________________________________________________
# conv2d_341 (Conv2D)             (None, 32, 32, 64)   36928       batch_normalization_184[2][0]
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_341[0][0]
#                                                                  batch_normalization_185[0][0]
#                                                                  batch_normalization_185[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_303 (TensorFlo [(None, 32, 32, 64)] 0           conv2d_342[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 32, 32, 64)   256         tf_op_layer_Relu_303[0][0]
#                                                                  tf_op_layer_Relu_304[0][0]
#                                                                  tf_op_layer_Relu_305[0][0]
# __________________________________________________________________________________________________
# add_147 (Add)                   (None, 32, 32, 64)   0           conv2d_341[0][0]
#                                                                  conv2d_342[1][0]
#                                                                  conv2d_341[0][0]
#                                                                  conv2d_342[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_304 (TensorFlo [(None, 32, 32, 64)] 0           add_147[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_305 (TensorFlo [(None, 32, 32, 64)] 0           add_147[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 16, 16, 64)   0           batch_normalization_185[2][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 16, 16, 128)  73856       max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_343[0][0]
#                                                                  batch_normalization_186[0][0]
#                                                                  batch_normalization_186[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_306 (TensorFlo [(None, 16, 16, 128) 0           conv2d_344[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 16, 16, 128)  512         tf_op_layer_Relu_306[0][0]
#                                                                  tf_op_layer_Relu_307[0][0]
#                                                                  tf_op_layer_Relu_308[0][0]
# __________________________________________________________________________________________________
# add_148 (Add)                   (None, 16, 16, 128)  0           conv2d_343[0][0]
#                                                                  conv2d_344[1][0]
#                                                                  conv2d_343[0][0]
#                                                                  conv2d_344[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_307 (TensorFlo [(None, 16, 16, 128) 0           add_148[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_308 (TensorFlo [(None, 16, 16, 128) 0           add_148[1][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 16, 16, 128)  147584      batch_normalization_186[2][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_345[0][0]
#                                                                  batch_normalization_187[0][0]
#                                                                  batch_normalization_187[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_309 (TensorFlo [(None, 16, 16, 128) 0           conv2d_346[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 16, 16, 128)  512         tf_op_layer_Relu_309[0][0]
#                                                                  tf_op_layer_Relu_310[0][0]
#                                                                  tf_op_layer_Relu_311[0][0]
# __________________________________________________________________________________________________
# add_149 (Add)                   (None, 16, 16, 128)  0           conv2d_345[0][0]
#                                                                  conv2d_346[1][0]
#                                                                  conv2d_345[0][0]
#                                                                  conv2d_346[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_310 (TensorFlo [(None, 16, 16, 128) 0           add_149[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_311 (TensorFlo [(None, 16, 16, 128) 0           add_149[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 8, 8, 128)    0           batch_normalization_187[2][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 8, 8, 256)    295168      max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 8, 8, 256)    590080      conv2d_347[0][0]
#                                                                  batch_normalization_188[0][0]
#                                                                  batch_normalization_188[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_312 (TensorFlo [(None, 8, 8, 256)]  0           conv2d_348[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 8, 8, 256)    1024        tf_op_layer_Relu_312[0][0]
#                                                                  tf_op_layer_Relu_313[0][0]
#                                                                  tf_op_layer_Relu_314[0][0]
# __________________________________________________________________________________________________
# add_150 (Add)                   (None, 8, 8, 256)    0           conv2d_347[0][0]
#                                                                  conv2d_348[1][0]
#                                                                  conv2d_347[0][0]
#                                                                  conv2d_348[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_313 (TensorFlo [(None, 8, 8, 256)]  0           add_150[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_314 (TensorFlo [(None, 8, 8, 256)]  0           add_150[1][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 8, 8, 256)    590080      batch_normalization_188[2][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 8, 8, 256)    590080      conv2d_349[0][0]
#                                                                  batch_normalization_189[0][0]
#                                                                  batch_normalization_189[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_315 (TensorFlo [(None, 8, 8, 256)]  0           conv2d_350[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 8, 8, 256)    1024        tf_op_layer_Relu_315[0][0]
#                                                                  tf_op_layer_Relu_316[0][0]
#                                                                  tf_op_layer_Relu_317[0][0]
# __________________________________________________________________________________________________
# add_151 (Add)                   (None, 8, 8, 256)    0           conv2d_349[0][0]
#                                                                  conv2d_350[1][0]
#                                                                  conv2d_349[0][0]
#                                                                  conv2d_350[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_316 (TensorFlo [(None, 8, 8, 256)]  0           add_151[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_317 (TensorFlo [(None, 8, 8, 256)]  0           add_151[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_36 (Conv2DTran (None, 16, 16, 128)  131200      batch_normalization_189[2][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 16, 16, 256)  0           conv2d_transpose_36[0][0]
#                                                                  batch_normalization_187[2][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 16, 16, 128)  295040      concatenate_36[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_351[0][0]
#                                                                  batch_normalization_190[0][0]
#                                                                  batch_normalization_190[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_318 (TensorFlo [(None, 16, 16, 128) 0           conv2d_352[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 16, 16, 128)  512         tf_op_layer_Relu_318[0][0]
#                                                                  tf_op_layer_Relu_319[0][0]
#                                                                  tf_op_layer_Relu_320[0][0]
# __________________________________________________________________________________________________
# add_152 (Add)                   (None, 16, 16, 128)  0           conv2d_351[0][0]
#                                                                  conv2d_352[1][0]
#                                                                  conv2d_351[0][0]
#                                                                  conv2d_352[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_319 (TensorFlo [(None, 16, 16, 128) 0           add_152[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_320 (TensorFlo [(None, 16, 16, 128) 0           add_152[1][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 16, 16, 128)  147584      batch_normalization_190[2][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_353[0][0]
#                                                                  batch_normalization_191[0][0]
#                                                                  batch_normalization_191[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_321 (TensorFlo [(None, 16, 16, 128) 0           conv2d_354[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 16, 16, 128)  512         tf_op_layer_Relu_321[0][0]
#                                                                  tf_op_layer_Relu_322[0][0]
#                                                                  tf_op_layer_Relu_323[0][0]
# __________________________________________________________________________________________________
# add_153 (Add)                   (None, 16, 16, 128)  0           conv2d_353[0][0]
#                                                                  conv2d_354[1][0]
#                                                                  conv2d_353[0][0]
#                                                                  conv2d_354[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_322 (TensorFlo [(None, 16, 16, 128) 0           add_153[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_323 (TensorFlo [(None, 16, 16, 128) 0           add_153[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_37 (Conv2DTran (None, 32, 32, 128)  65664       batch_normalization_191[2][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 32, 32, 192)  0           conv2d_transpose_37[0][0]
#                                                                  batch_normalization_185[2][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 32, 32, 64)   110656      concatenate_37[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_355[0][0]
#                                                                  batch_normalization_192[0][0]
#                                                                  batch_normalization_192[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_324 (TensorFlo [(None, 32, 32, 64)] 0           conv2d_356[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 32, 32, 64)   256         tf_op_layer_Relu_324[0][0]
#                                                                  tf_op_layer_Relu_325[0][0]
#                                                                  tf_op_layer_Relu_326[0][0]
# __________________________________________________________________________________________________
# add_154 (Add)                   (None, 32, 32, 64)   0           conv2d_355[0][0]
#                                                                  conv2d_356[1][0]
#                                                                  conv2d_355[0][0]
#                                                                  conv2d_356[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_325 (TensorFlo [(None, 32, 32, 64)] 0           add_154[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_326 (TensorFlo [(None, 32, 32, 64)] 0           add_154[1][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 32, 32, 64)   36928       batch_normalization_192[2][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_357[0][0]
#                                                                  batch_normalization_193[0][0]
#                                                                  batch_normalization_193[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_327 (TensorFlo [(None, 32, 32, 64)] 0           conv2d_358[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 32, 32, 64)   256         tf_op_layer_Relu_327[0][0]
#                                                                  tf_op_layer_Relu_328[0][0]
#                                                                  tf_op_layer_Relu_329[0][0]
# __________________________________________________________________________________________________
# add_155 (Add)                   (None, 32, 32, 64)   0           conv2d_357[0][0]
#                                                                  conv2d_358[1][0]
#                                                                  conv2d_357[0][0]
#                                                                  conv2d_358[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_328 (TensorFlo [(None, 32, 32, 64)] 0           add_155[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_329 (TensorFlo [(None, 32, 32, 64)] 0           add_155[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_38 (Conv2DTran (None, 64, 64, 64)   16448       batch_normalization_193[2][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 64, 64, 96)   0           conv2d_transpose_38[0][0]
#                                                                  batch_normalization_183[2][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, 64, 64, 32)   27680       concatenate_38[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_359[0][0]
#                                                                  batch_normalization_194[0][0]
#                                                                  batch_normalization_194[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_330 (TensorFlo [(None, 64, 64, 32)] 0           conv2d_360[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 64, 64, 32)   128         tf_op_layer_Relu_330[0][0]
#                                                                  tf_op_layer_Relu_331[0][0]
#                                                                  tf_op_layer_Relu_332[0][0]
# __________________________________________________________________________________________________
# add_156 (Add)                   (None, 64, 64, 32)   0           conv2d_359[0][0]
#                                                                  conv2d_360[1][0]
#                                                                  conv2d_359[0][0]
#                                                                  conv2d_360[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_331 (TensorFlo [(None, 64, 64, 32)] 0           add_156[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_332 (TensorFlo [(None, 64, 64, 32)] 0           add_156[1][0]
# __________________________________________________________________________________________________
# conv2d_361 (Conv2D)             (None, 64, 64, 32)   9248        batch_normalization_194[2][0]
# __________________________________________________________________________________________________
# conv2d_362 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_361[0][0]
#                                                                  batch_normalization_195[0][0]
#                                                                  batch_normalization_195[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_333 (TensorFlo [(None, 64, 64, 32)] 0           conv2d_362[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 64, 64, 32)   128         tf_op_layer_Relu_333[0][0]
#                                                                  tf_op_layer_Relu_334[0][0]
#                                                                  tf_op_layer_Relu_335[0][0]
# __________________________________________________________________________________________________
# add_157 (Add)                   (None, 64, 64, 32)   0           conv2d_361[0][0]
#                                                                  conv2d_362[1][0]
#                                                                  conv2d_361[0][0]
#                                                                  conv2d_362[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_334 (TensorFlo [(None, 64, 64, 32)] 0           add_157[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_335 (TensorFlo [(None, 64, 64, 32)] 0           add_157[1][0]
# __________________________________________________________________________________________________
# conv2d_transpose_39 (Conv2DTran (None, 128, 128, 32) 4128        batch_normalization_195[2][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 128, 128, 48) 0           conv2d_transpose_39[0][0]
#                                                                  batch_normalization_181[2][0]
# __________________________________________________________________________________________________
# conv2d_364 (Conv2D)             (None, 128, 128, 16) 6928        concatenate_39[0][0]
# __________________________________________________________________________________________________
# conv2d_365 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_364[0][0]
#                                                                  batch_normalization_196[0][0]
#                                                                  batch_normalization_196[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_336 (TensorFlo [(None, 128, 128, 16 0           conv2d_365[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 128, 128, 16) 64          tf_op_layer_Relu_336[0][0]
#                                                                  tf_op_layer_Relu_337[0][0]
#                                                                  tf_op_layer_Relu_338[0][0]
# __________________________________________________________________________________________________
# add_158 (Add)                   (None, 128, 128, 16) 0           conv2d_364[0][0]
#                                                                  conv2d_365[1][0]
#                                                                  conv2d_364[0][0]
#                                                                  conv2d_365[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_337 (TensorFlo [(None, 128, 128, 16 0           add_158[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_338 (TensorFlo [(None, 128, 128, 16 0           add_158[1][0]
# __________________________________________________________________________________________________
# conv2d_366 (Conv2D)             (None, 128, 128, 16) 2320        batch_normalization_196[2][0]
# __________________________________________________________________________________________________
# conv2d_367 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_366[0][0]
#                                                                  batch_normalization_197[0][0]
#                                                                  batch_normalization_197[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_339 (TensorFlo [(None, 128, 128, 16 0           conv2d_367[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 128, 128, 16) 64          tf_op_layer_Relu_339[0][0]
#                                                                  tf_op_layer_Relu_340[0][0]
#                                                                  tf_op_layer_Relu_341[0][0]
# __________________________________________________________________________________________________
# add_159 (Add)                   (None, 128, 128, 16) 0           conv2d_366[0][0]
#                                                                  conv2d_367[1][0]
#                                                                  conv2d_366[0][0]
#                                                                  conv2d_367[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_340 (TensorFlo [(None, 128, 128, 16 0           add_159[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_341 (TensorFlo [(None, 128, 128, 16 0           add_159[1][0]
# __________________________________________________________________________________________________
# conv2d_363 (Conv2D)             (None, 128, 128, 1)  17          batch_normalization_197[2][0]
# ==================================================================================================
# Total params: 4,002,977
# Trainable params: 4,000,033
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
#Training: RUnet
training_loader = DataLoader(training_img_ids, training_path, img_size=img_size, batch_size=batch_size)
test_loader = DataLoader(test_img_ids, test_path, img_size=img_size, batch_size=batch_size)

train_steps = len(training_img_ids)//batch_size
test_steps = len(test_img_ids)//batch_size

model.fit_generator(training_loader, validation_data=test_loader, steps_per_epoch=train_steps, validation_steps=test_steps, 
                    epochs=epochs)
# Out:
# Epoch 1/15
# 81/81 [==============================] - 588s 7s/step - loss: 1.9129 - acc: 0.7717 - val_loss: 1.7731 - val_acc: 0.8552
# Epoch 2/15
# 49/81 [=================>............] - ETA: 3:50 - loss: 1.0877 - acc: 0.8192

# %%
#Training: RUnet
training_loader = DataLoader(training_img_ids, training_path, img_size=img_size, batch_size=batch_size)
test_loader = DataLoader(test_img_ids, test_path, img_size=img_size, batch_size=batch_size)

train_steps = len(training_img_ids)//batch_size
test_steps = len(test_img_ids)//batch_size

model.fit_generator(training_loader, validation_data=test_loader, steps_per_epoch=train_steps, validation_steps=test_steps, 
                    epochs=epochs)
# Out:
# Epoch 1/15
# 81/81 [==============================] - 510s 6s/step - loss: 1.9441 - acc: 0.7794 - val_loss: 2.8627 - val_acc: 0.7241
# Epoch 2/15
# 81/81 [==============================] - 479s 6s/step - loss: 0.9382 - acc: 0.8287 - val_loss: 7.2121 - val_acc: 0.4432
# Epoch 3/15
# 81/81 [==============================] - 487s 6s/step - loss: 0.6075 - acc: 0.8472 - val_loss: 3.1023 - val_acc: 0.7803
# Epoch 4/15
# 81/81 [==============================] - 476s 6s/step - loss: 0.4395 - acc: 0.8510 - val_loss: 0.1457 - val_acc: 0.9904
# Epoch 5/15
# 81/81 [==============================] - 479s 6s/step - loss: 0.3570 - acc: 0.8740 - val_loss: 0.1491 - val_acc: 0.9819
# Epoch 6/15
# 81/81 [==============================] - 521s 6s/step - loss: 0.3113 - acc: 0.8808 - val_loss: 0.1377 - val_acc: 0.9905
# Epoch 7/15
# 81/81 [==============================] - 516s 6s/step - loss: 0.3306 - acc: 0.8748 - val_loss: 1.3518 - val_acc: 0.8723
# Epoch 8/15
# 81/81 [==============================] - 540s 7s/step - loss: 0.2796 - acc: 0.8859 - val_loss: 0.6341 - val_acc: 0.9355
# Epoch 9/15
# 81/81 [==============================] - 579s 7s/step - loss: 0.2716 - acc: 0.8885 - val_loss: 0.4154 - val_acc: 0.9411
# Epoch 10/15
# 81/81 [==============================] - 575s 7s/step - loss: 0.2757 - acc: 0.8802 - val_loss: 3.0249 - val_acc: 0.7264
# Epoch 11/15
# 81/81 [==============================] - 542s 7s/step - loss: 0.2833 - acc: 0.8801 - val_loss: 0.1457 - val_acc: 0.9833
# Epoch 12/15
# 81/81 [==============================] - 517s 6s/step - loss: 0.2536 - acc: 0.8870 - val_loss: 0.7382 - val_acc: 0.8526
# Epoch 13/15
# 81/81 [==============================] - 511s 6s/step - loss: 0.2413 - acc: 0.8922 - val_loss: 0.1360 - val_acc: 0.9906
# Epoch 14/15
# 81/81 [==============================] - 518s 6s/step - loss: 0.2166 - acc: 0.8993 - val_loss: 0.1351 - val_acc: 0.9906
# Epoch 15/15
# 81/81 [==============================] - 515s 6s/step - loss: 0.2110 - acc: 0.9033 - val_loss: 0.1350 - val_acc: 0.9906

# %%
def residual_recurrent_down_block(x,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    pool = layers.MaxPool2D((2,2),(2,2))
    res = layers.Conv2D(filters=filters,kernel_size=1,padding="SAME",strides=1,kernel_initializer=tf.constant_initializer())
    add = layers.Add()
    r = res(x)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    
    c = add([r,x])
    p = pool(c)
    return c,p

def residual_recurrent_plateau_block(x,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    conv_transpose = layers.Conv2DTranspose(filters//2,kernel_size=(2,2),strides=(2,2))
    res = layers.Conv2D(filters,kernel_size=1,padding="SAME",strides=1,kernel_initializer=tf.constant_initializer())
    add = layers.Add()
    r = res(x)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    x = add([r,x])
    up = conv_transpose(x)
    return up

def residual_recurrent_up_block(x,p,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    res = layers.Conv2D(filters,kernel_size=1,padding="SAME",strides=1,kernel_initializer=tf.constant_initializer())
    add = layers.Add()
    concat = layers.Concatenate()([x,p])
    r = res(concat)
    conv_transpose = layers.Conv2DTranspose(filters,kernel_size=(2,2),strides=(2,2))
    x = _recurrent_conv_layer(concat,filters,kernel_size,padding,strides,time_steps)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    x = add([r,x])
    up = conv_transpose(x)
    return up

def residual_recurrent_output_layer(x,p,filters,kernel_size=3,padding="SAME",strides=1,time_steps=2):
    concat = layers.Concatenate()([x,p])
    out_conv = keras.layers.Conv2D(1, (1, 1), padding="same", activation="relu")
    x = _recurrent_conv_layer(concat,filters,kernel_size,padding,strides,time_steps)
    x = _recurrent_conv_layer(x,filters,kernel_size,padding,strides,time_steps)
    outs = out_conv(x)
    return outs

# %%
def R2UNet():
    inputs = keras.layers.Input((img_size, img_size, 3)) #3 because of rgb
    #inputs = tf.random.normal((1,224,224,3))
    #downsampling
    p0 = inputs
    print(p0.shape)
    c1, p1 = residual_recurrent_down_block(p0, f[0]) #16
    print(c1.shape,p1.shape)
    c2, p2 = residual_recurrent_down_block(p1, f[1]) #32
    print(c2.shape,p2.shape)
    c3, p3 = residual_recurrent_down_block(p2, f[2]) #64
    print(c3.shape,p3.shape)
    c4, p4 = residual_recurrent_down_block(p3, f[3]) #128
    print(c4.shape,p4.shape)
    #convolution_block before upsampling
    cn = residual_recurrent_plateau_block(p4, f[4]) #128
    print(cn.shape)
    
    #upsampling
    u1 = residual_recurrent_up_block(cn, c4, f[3]) #128
    print(cn.shape,c4.shape)
    u2 = residual_recurrent_up_block(u1, c3, f[2]) #64
    print(u1.shape,c3.shape)
    u3 = residual_recurrent_up_block(u2, c2, f[1]) #32
    print(u2.shape,c2.shape)
    outputs = residual_recurrent_output_layer(u3, c1, f[0]) #16
    print(u3.shape,c1.shape)
    
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model = R2UNet()
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"]) #Configures the model for training.
model.summary()
# Out:
# (None, 128, 128, 3)
# (None, 128, 128, 16) (None, 64, 64, 16)
# (None, 64, 64, 32) (None, 32, 32, 32)
# (None, 32, 32, 64) (None, 16, 16, 64)
# (None, 16, 16, 128) (None, 8, 8, 128)
# (None, 16, 16, 128)
# (None, 16, 16, 128) (None, 16, 16, 128)
# (None, 32, 32, 128) (None, 32, 32, 64)
# (None, 64, 64, 64) (None, 64, 64, 32)
# (None, 128, 128, 32) (None, 128, 128, 16)
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 128, 128, 16) 448         input_6[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_194[0][0]
#                                                                  batch_normalization_108[0][0]
#                                                                  batch_normalization_108[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_108 (TensorFlo [(None, 128, 128, 16 0           conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 128, 128, 16) 64          tf_op_layer_Relu_108[0][0]
#                                                                  tf_op_layer_Relu_109[0][0]
#                                                                  tf_op_layer_Relu_110[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 128, 128, 16) 0           conv2d_194[0][0]
#                                                                  conv2d_195[1][0]
#                                                                  conv2d_194[0][0]
#                                                                  conv2d_195[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_109 (TensorFlo [(None, 128, 128, 16 0           add_81[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_110 (TensorFlo [(None, 128, 128, 16 0           add_81[1][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 128, 128, 16) 2320        batch_normalization_108[2][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_196[0][0]
#                                                                  batch_normalization_109[0][0]
#                                                                  batch_normalization_109[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_111 (TensorFlo [(None, 128, 128, 16 0           conv2d_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 128, 128, 16) 64          tf_op_layer_Relu_111[0][0]
#                                                                  tf_op_layer_Relu_112[0][0]
#                                                                  tf_op_layer_Relu_113[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 128, 128, 16) 0           conv2d_196[0][0]
#                                                                  conv2d_197[1][0]
#                                                                  conv2d_196[0][0]
#                                                                  conv2d_197[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_112 (TensorFlo [(None, 128, 128, 16 0           add_82[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_113 (TensorFlo [(None, 128, 128, 16 0           add_82[1][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 128, 128, 16) 64          input_6[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 128, 128, 16) 0           conv2d_193[0][0]
#                                                                  batch_normalization_109[2][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 64, 64, 16)   0           add_80[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_199[0][0]
#                                                                  batch_normalization_110[0][0]
#                                                                  batch_normalization_110[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_114 (TensorFlo [(None, 64, 64, 32)] 0           conv2d_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 64, 64, 32)   128         tf_op_layer_Relu_114[0][0]
#                                                                  tf_op_layer_Relu_115[0][0]
#                                                                  tf_op_layer_Relu_116[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 64, 64, 32)   0           conv2d_199[0][0]
#                                                                  conv2d_200[1][0]
#                                                                  conv2d_199[0][0]
#                                                                  conv2d_200[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_115 (TensorFlo [(None, 64, 64, 32)] 0           add_84[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_116 (TensorFlo [(None, 64, 64, 32)] 0           add_84[1][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 64, 64, 32)   9248        batch_normalization_110[2][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_201[0][0]
#                                                                  batch_normalization_111[0][0]
#                                                                  batch_normalization_111[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_117 (TensorFlo [(None, 64, 64, 32)] 0           conv2d_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 64, 64, 32)   128         tf_op_layer_Relu_117[0][0]
#                                                                  tf_op_layer_Relu_118[0][0]
#                                                                  tf_op_layer_Relu_119[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 64, 64, 32)   0           conv2d_201[0][0]
#                                                                  conv2d_202[1][0]
#                                                                  conv2d_201[0][0]
#                                                                  conv2d_202[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_118 (TensorFlo [(None, 64, 64, 32)] 0           add_85[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_119 (TensorFlo [(None, 64, 64, 32)] 0           add_85[1][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 64, 64, 32)   544         max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 64, 64, 32)   0           conv2d_198[0][0]
#                                                                  batch_normalization_111[2][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 32, 32, 32)   0           add_83[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_204[0][0]
#                                                                  batch_normalization_112[0][0]
#                                                                  batch_normalization_112[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_120 (TensorFlo [(None, 32, 32, 64)] 0           conv2d_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 32, 32, 64)   256         tf_op_layer_Relu_120[0][0]
#                                                                  tf_op_layer_Relu_121[0][0]
#                                                                  tf_op_layer_Relu_122[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 32, 32, 64)   0           conv2d_204[0][0]
#                                                                  conv2d_205[1][0]
#                                                                  conv2d_204[0][0]
#                                                                  conv2d_205[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_121 (TensorFlo [(None, 32, 32, 64)] 0           add_87[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_122 (TensorFlo [(None, 32, 32, 64)] 0           add_87[1][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 32, 32, 64)   36928       batch_normalization_112[2][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_206[0][0]
#                                                                  batch_normalization_113[0][0]
#                                                                  batch_normalization_113[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_123 (TensorFlo [(None, 32, 32, 64)] 0           conv2d_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 32, 32, 64)   256         tf_op_layer_Relu_123[0][0]
#                                                                  tf_op_layer_Relu_124[0][0]
#                                                                  tf_op_layer_Relu_125[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 32, 32, 64)   0           conv2d_206[0][0]
#                                                                  conv2d_207[1][0]
#                                                                  conv2d_206[0][0]
#                                                                  conv2d_207[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_124 (TensorFlo [(None, 32, 32, 64)] 0           add_88[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_125 (TensorFlo [(None, 32, 32, 64)] 0           add_88[1][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 32, 32, 64)   2112        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 32, 32, 64)   0           conv2d_203[0][0]
#                                                                  batch_normalization_113[2][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 16, 16, 64)   0           add_86[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 16, 16, 128)  73856       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_209[0][0]
#                                                                  batch_normalization_114[0][0]
#                                                                  batch_normalization_114[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_126 (TensorFlo [(None, 16, 16, 128) 0           conv2d_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 16, 16, 128)  512         tf_op_layer_Relu_126[0][0]
#                                                                  tf_op_layer_Relu_127[0][0]
#                                                                  tf_op_layer_Relu_128[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 16, 16, 128)  0           conv2d_209[0][0]
#                                                                  conv2d_210[1][0]
#                                                                  conv2d_209[0][0]
#                                                                  conv2d_210[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_127 (TensorFlo [(None, 16, 16, 128) 0           add_90[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_128 (TensorFlo [(None, 16, 16, 128) 0           add_90[1][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 16, 16, 128)  147584      batch_normalization_114[2][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_211[0][0]
#                                                                  batch_normalization_115[0][0]
#                                                                  batch_normalization_115[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_129 (TensorFlo [(None, 16, 16, 128) 0           conv2d_212[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 16, 16, 128)  512         tf_op_layer_Relu_129[0][0]
#                                                                  tf_op_layer_Relu_130[0][0]
#                                                                  tf_op_layer_Relu_131[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 16, 16, 128)  0           conv2d_211[0][0]
#                                                                  conv2d_212[1][0]
#                                                                  conv2d_211[0][0]
#                                                                  conv2d_212[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_130 (TensorFlo [(None, 16, 16, 128) 0           add_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_131 (TensorFlo [(None, 16, 16, 128) 0           add_91[1][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 16, 16, 128)  8320        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 16, 16, 128)  0           conv2d_208[0][0]
#                                                                  batch_normalization_115[2][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 8, 8, 128)    0           add_89[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 8, 8, 256)    295168      max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 8, 8, 256)    590080      conv2d_214[0][0]
#                                                                  batch_normalization_116[0][0]
#                                                                  batch_normalization_116[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_132 (TensorFlo [(None, 8, 8, 256)]  0           conv2d_215[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 8, 8, 256)    1024        tf_op_layer_Relu_132[0][0]
#                                                                  tf_op_layer_Relu_133[0][0]
#                                                                  tf_op_layer_Relu_134[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 8, 8, 256)    0           conv2d_214[0][0]
#                                                                  conv2d_215[1][0]
#                                                                  conv2d_214[0][0]
#                                                                  conv2d_215[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_133 (TensorFlo [(None, 8, 8, 256)]  0           add_93[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_134 (TensorFlo [(None, 8, 8, 256)]  0           add_93[1][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 8, 8, 256)    590080      batch_normalization_116[2][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 8, 8, 256)    590080      conv2d_216[0][0]
#                                                                  batch_normalization_117[0][0]
#                                                                  batch_normalization_117[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_135 (TensorFlo [(None, 8, 8, 256)]  0           conv2d_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 8, 8, 256)    1024        tf_op_layer_Relu_135[0][0]
#                                                                  tf_op_layer_Relu_136[0][0]
#                                                                  tf_op_layer_Relu_137[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 8, 8, 256)    0           conv2d_216[0][0]
#                                                                  conv2d_217[1][0]
#                                                                  conv2d_216[0][0]
#                                                                  conv2d_217[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_136 (TensorFlo [(None, 8, 8, 256)]  0           add_94[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_137 (TensorFlo [(None, 8, 8, 256)]  0           add_94[1][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 8, 8, 256)    33024       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 8, 8, 256)    0           conv2d_213[0][0]
#                                                                  batch_normalization_117[2][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 16, 16, 128)  131200      add_92[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 16, 16, 256)  0           conv2d_transpose_20[0][0]
#                                                                  add_89[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 16, 16, 128)  295040      concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_219[0][0]
#                                                                  batch_normalization_118[0][0]
#                                                                  batch_normalization_118[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_138 (TensorFlo [(None, 16, 16, 128) 0           conv2d_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 16, 16, 128)  512         tf_op_layer_Relu_138[0][0]
#                                                                  tf_op_layer_Relu_139[0][0]
#                                                                  tf_op_layer_Relu_140[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 16, 16, 128)  0           conv2d_219[0][0]
#                                                                  conv2d_220[1][0]
#                                                                  conv2d_219[0][0]
#                                                                  conv2d_220[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_139 (TensorFlo [(None, 16, 16, 128) 0           add_96[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_140 (TensorFlo [(None, 16, 16, 128) 0           add_96[1][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 16, 16, 128)  147584      batch_normalization_118[2][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 16, 16, 128)  147584      conv2d_221[0][0]
#                                                                  batch_normalization_119[0][0]
#                                                                  batch_normalization_119[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_141 (TensorFlo [(None, 16, 16, 128) 0           conv2d_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 16, 16, 128)  512         tf_op_layer_Relu_141[0][0]
#                                                                  tf_op_layer_Relu_142[0][0]
#                                                                  tf_op_layer_Relu_143[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 16, 16, 128)  0           conv2d_221[0][0]
#                                                                  conv2d_222[1][0]
#                                                                  conv2d_221[0][0]
#                                                                  conv2d_222[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_142 (TensorFlo [(None, 16, 16, 128) 0           add_97[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_143 (TensorFlo [(None, 16, 16, 128) 0           add_97[1][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 16, 16, 128)  32896       concatenate_20[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 16, 16, 128)  0           conv2d_218[0][0]
#                                                                  batch_normalization_119[2][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 32, 32, 128)  65664       add_95[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 32, 32, 192)  0           conv2d_transpose_21[0][0]
#                                                                  add_86[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 32, 32, 64)   110656      concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_224[0][0]
#                                                                  batch_normalization_120[0][0]
#                                                                  batch_normalization_120[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_144 (TensorFlo [(None, 32, 32, 64)] 0           conv2d_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 32, 32, 64)   256         tf_op_layer_Relu_144[0][0]
#                                                                  tf_op_layer_Relu_145[0][0]
#                                                                  tf_op_layer_Relu_146[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 32, 32, 64)   0           conv2d_224[0][0]
#                                                                  conv2d_225[1][0]
#                                                                  conv2d_224[0][0]
#                                                                  conv2d_225[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_145 (TensorFlo [(None, 32, 32, 64)] 0           add_99[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_146 (TensorFlo [(None, 32, 32, 64)] 0           add_99[1][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 32, 32, 64)   36928       batch_normalization_120[2][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_226[0][0]
#                                                                  batch_normalization_121[0][0]
#                                                                  batch_normalization_121[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_147 (TensorFlo [(None, 32, 32, 64)] 0           conv2d_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 32, 32, 64)   256         tf_op_layer_Relu_147[0][0]
#                                                                  tf_op_layer_Relu_148[0][0]
#                                                                  tf_op_layer_Relu_149[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, 32, 32, 64)   0           conv2d_226[0][0]
#                                                                  conv2d_227[1][0]
#                                                                  conv2d_226[0][0]
#                                                                  conv2d_227[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_148 (TensorFlo [(None, 32, 32, 64)] 0           add_100[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_149 (TensorFlo [(None, 32, 32, 64)] 0           add_100[1][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 32, 32, 64)   12352       concatenate_21[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 32, 32, 64)   0           conv2d_223[0][0]
#                                                                  batch_normalization_121[2][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 64, 64, 64)   16448       add_98[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 64, 64, 96)   0           conv2d_transpose_22[0][0]
#                                                                  add_83[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 64, 64, 32)   27680       concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_229[0][0]
#                                                                  batch_normalization_122[0][0]
#                                                                  batch_normalization_122[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_150 (TensorFlo [(None, 64, 64, 32)] 0           conv2d_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 64, 64, 32)   128         tf_op_layer_Relu_150[0][0]
#                                                                  tf_op_layer_Relu_151[0][0]
#                                                                  tf_op_layer_Relu_152[0][0]
# __________________________________________________________________________________________________
# add_102 (Add)                   (None, 64, 64, 32)   0           conv2d_229[0][0]
#                                                                  conv2d_230[1][0]
#                                                                  conv2d_229[0][0]
#                                                                  conv2d_230[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_151 (TensorFlo [(None, 64, 64, 32)] 0           add_102[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_152 (TensorFlo [(None, 64, 64, 32)] 0           add_102[1][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 64, 64, 32)   9248        batch_normalization_122[2][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_231[0][0]
#                                                                  batch_normalization_123[0][0]
#                                                                  batch_normalization_123[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_153 (TensorFlo [(None, 64, 64, 32)] 0           conv2d_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 64, 64, 32)   128         tf_op_layer_Relu_153[0][0]
#                                                                  tf_op_layer_Relu_154[0][0]
#                                                                  tf_op_layer_Relu_155[0][0]
# __________________________________________________________________________________________________
# add_103 (Add)                   (None, 64, 64, 32)   0           conv2d_231[0][0]
#                                                                  conv2d_232[1][0]
#                                                                  conv2d_231[0][0]
#                                                                  conv2d_232[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_154 (TensorFlo [(None, 64, 64, 32)] 0           add_103[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_155 (TensorFlo [(None, 64, 64, 32)] 0           add_103[1][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 64, 64, 32)   3104        concatenate_22[0][0]
# __________________________________________________________________________________________________
# add_101 (Add)                   (None, 64, 64, 32)   0           conv2d_228[0][0]
#                                                                  batch_normalization_123[2][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 128, 128, 32) 4128        add_101[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 128, 128, 48) 0           conv2d_transpose_23[0][0]
#                                                                  add_80[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 128, 128, 16) 6928        concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_234[0][0]
#                                                                  batch_normalization_124[0][0]
#                                                                  batch_normalization_124[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_156 (TensorFlo [(None, 128, 128, 16 0           conv2d_235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 128, 128, 16) 64          tf_op_layer_Relu_156[0][0]
#                                                                  tf_op_layer_Relu_157[0][0]
#                                                                  tf_op_layer_Relu_158[0][0]
# __________________________________________________________________________________________________
# add_104 (Add)                   (None, 128, 128, 16) 0           conv2d_234[0][0]
#                                                                  conv2d_235[1][0]
#                                                                  conv2d_234[0][0]
#                                                                  conv2d_235[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_157 (TensorFlo [(None, 128, 128, 16 0           add_104[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_158 (TensorFlo [(None, 128, 128, 16 0           add_104[1][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 128, 128, 16) 2320        batch_normalization_124[2][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 128, 128, 16) 2320        conv2d_236[0][0]
#                                                                  batch_normalization_125[0][0]
#                                                                  batch_normalization_125[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_159 (TensorFlo [(None, 128, 128, 16 0           conv2d_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 128, 128, 16) 64          tf_op_layer_Relu_159[0][0]
#                                                                  tf_op_layer_Relu_160[0][0]
#                                                                  tf_op_layer_Relu_161[0][0]
# __________________________________________________________________________________________________
# add_105 (Add)                   (None, 128, 128, 16) 0           conv2d_236[0][0]
#                                                                  conv2d_237[1][0]
#                                                                  conv2d_236[0][0]
#                                                                  conv2d_237[2][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_160 (TensorFlo [(None, 128, 128, 16 0           add_105[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu_161 (TensorFlo [(None, 128, 128, 16 0           add_105[1][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 128, 128, 1)  17          batch_normalization_125[2][0]
# ==================================================================================================
# Total params: 4,095,393
# Trainable params: 4,092,449
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
#Training: R2Unet
training_loader = DataLoader(training_img_ids, training_path, img_size=img_size, batch_size=batch_size)
test_loader = DataLoader(test_img_ids, test_path, img_size=img_size, batch_size=batch_size)

train_steps = len(training_img_ids)//batch_size
test_steps = len(test_img_ids)//batch_size

model.fit_generator(training_loader, validation_data=test_loader, steps_per_epoch=train_steps, validation_steps=test_steps, 
                    epochs=epochs)
# Out:
# Epoch 1/15
# 55/81 [===================>..........] - ETA: 3:11 - loss: 2.8378 - acc: 0.6872
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-4dab9d57fa1f> in <module>
#       7
#       8 model.fit_generator(training_loader, validation_data=test_loader, steps_per_epoch=train_steps, validation_steps=test_steps,
# ----> 9                     epochs=epochs)
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1295         shuffle=shuffle,
#    1296         initial_epoch=initial_epoch,
# -> 1297         steps_name='steps_per_epoch')
#    1298
#    1299   def evaluate_generator(self,
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#     971       outputs = training_v2_utils.train_on_batch(
#     972           self, x, y=y, sample_weight=sample_weight,
# --> 973           class_weight=class_weight, reset_metrics=reset_metrics)
#     974       outputs = (outputs['total_loss'] + outputs['output_losses'] +
#     975                  outputs['metrics'])
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     250               output_loss_metrics=output_loss_metrics,
#     251               sample_weights=sample_weights,
# --> 252               training=training))
#     253       if total_loss is None:
#     254         raise ValueError('The model cannot be run '
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _model_loss(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     125     inputs = nest.map_structure(ops.convert_to_tensor, inputs)
#     126
# --> 127   outs = model(inputs, **kwargs)
#     128   outs = nest.flatten(outs)
#     129
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py in call(self, inputs, training, mask)
#     706     return self._run_internal_graph(
#     707         inputs, training=training, mask=mask,
# --> 708         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     709
#     710   def compute_output_shape(self, input_shape):
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     858
#     859           # Compute outputs.
# --> 860           output_tensors = layer(computed_tensors, **kwargs)
#     861
#     862           # Update tensor_dict.
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in call(self, inputs)
#    2481   def call(self, inputs):
#    2482     if context.executing_eagerly():
# -> 2483       return self._defun_call(inputs)
#    2484     return self._make_op(inputs)
#    2485
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
